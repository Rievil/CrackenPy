# %%
from crackest.cracks import CrackPy
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

cp=CrackPy(model=1)
# Out:
# resnet50
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /Users/richarddvorak/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:1344, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1343 try:
# -> 1344     h.request(req.get_method(), req.selector, req.data, headers,
#    1345               encode_chunked=req.has_header('Transfer-encoding'))
#    1346 except OSError as err: # timeout error
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1336, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1335 """Send a complete request to the server."""
# ...

# %%
cp.get_mask(impath=r"../Img/ID14_940_Image.png")
cp.distancemap()

# %%
cp.show_mask(mask="crack")

# %%
cp.overlay(figsize=(12,3))

# %%
cp.save(r"../Plots/Example.png")

# %%
cp.get_metrics()
# Out:
# {'edge_per_node': np.float64(1.2531120331950207),
#  'crack_tot_length': np.float64(19352.349118015452),
#  'average_angle': np.float64(92.92066601641301),
#  'spec_area': (np.uint64(6030737),),
#  'mat_area': (np.uint64(1231883),),
#  'crack_ratio': (np.float64(0.0289845171493965),),
#  'crack_length': (np.int64(18480),),
#  'crack_thickness': (np.float64(9.458766233766234),),
#  'pore_area': (np.uint64(35242),),
#  'avg_pore_distance': np.float64(1899.250237559361),
#  'avg_pore_size': np.float64(152.1818181818182)}

# %%
from crackest.crack_analyzer import CrackAn

ca=CrackAn()
ca.input(file=r"../Img/256_Image_29-01-2022 02-36-02.png")
ca.registr()
# Out:
# ...
# ... done downloading
# /Users/richarddvorak/Documents/GitHub/CrackPy/.venv/lib/python3.12/site-packages/crackpy_models/model1.pt
#                       bbox                sbbox     angle       area  \
# 2  [2320, 553, 3326, 4460]  [18, 1005, 0, 3894]  0.122378  3780307.0
# 0  [1239, 600, 2232, 4412]    [9, 992, 0, 3800]  0.509065  3631122.0
# 1   [145, 681, 1128, 4464]   [10, 982, 0, 3766]  0.597327  3544366.0
#
#             x0           y0  \
# 2  2492.805440  2840.724969
# 0  2507.339556  1746.155873
# 1  2562.672774   647.192809
#
#                                              subspec  \
# 2  {'img': [[[2 2 2], [3 2 2], [2 2 2], [2 2 3], ...
# 0  {'img': [[[2 2 2], [2 2 3], [2 2 3], [2 2 2], ...
# 1  {'img': [[[3 3 3], [3 3 3], [3 3 2], [3 3 3], ...
#
#                                                   eq  \
# 2  {'h': {'alpha': 468.184647007102, 'beta': -116...
# 0  {'h': {'alpha': 112.54813312845477, 'beta': -2...
# 1  {'h': {'alpha': 95.91687828251288, 'beta': -24...
#
# ...

# %%
ca.preview()
ca.fig.savefig(r"../Plots/Multiple_registr.png")

# %%
spec=ca.get_spec(specid=2,frame=50,imgindex=0)
spec.set_ratio(160,40)
spec.show_img()
# Out:
# Pixel to mm ratio: 0.04 mm/px

# %%
spec.get_metrics()
# Out:
# {'edge_per_node': np.float64(1.0229885057471264),
#  'crack_tot_length': np.float64(3625.52099474892),
#  'average_angle': np.float64(87.44230534045455),
#  'spec_area': (np.float64(154855.08194901986),),
#  'mat_area': (np.float64(23171.222146466414),),
#  'crack_ratio': (np.float64(0.004880658775802474),),
#  'crack_length': (np.float64(188.3406876644768),),
#  'crack_thickness': (np.float64(0.16541799402322063),),
#  'pore_area': (np.float64(179.80785283266533),),
#  'avg_pore_distance': np.float64(1322.185075956184),
#  'avg_pore_size': np.float64(110.7948717948718)}

# %%
spec.save(r"../Plots/Subspec.png")
